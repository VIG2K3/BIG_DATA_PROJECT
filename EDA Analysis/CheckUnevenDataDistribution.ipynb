# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('database/student_performance_cleaned.csv')

# %%
#Identify Categorical and Numerical Data

# Get numeric columns
num_cols = df.select_dtypes(include="number").columns.tolist()

# Remove the index column if it exists
if "index" in num_cols:
    num_cols.remove("index")

# Get categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print results
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables (index removed):")
print(num_cols)
# Out:
# Categorical Variables:
# ['resources', 'extracurricular', 'motivation', 'internet', 'gender', 'learningstyle', 'discussions', 'edutech', 'stresslevel', 'finalgrade']
# Numerical Variables (index removed):
# ['studyhours', 'attendance', 'age', 'onlinecourses', 'assignmentcompletion', 'examscore']

# %%
#Check Data Distribution for Gender
df['gender'].value_counts()
# Out:
# gender
# Female    6320
# Male      5470
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# Female    53.60475
# Male      46.39525
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='gender', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Extracurriculars
df['extracurricular'].value_counts()
# Out:
# extracurricular
# Yes    6836
# No     4954
# Name: count, dtype: int64

# %%
df['extracurricular'].value_counts(normalize=True) * 100
# Out:
# extracurricular
# Yes    57.98134
# No     42.01866
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='extracurricular', data=df)
plt.title('Distribution of Extracurricular Participation')
plt.xlabel('Extracurricular')
plt.ylabel('Count')
plt.show()

# %%
df['motivation'].value_counts()
# Out:
# motivation
# Medium    5682
# Low       3609
# High      2499
# Name: count, dtype: int64

# %%
df['motivation'].value_counts(normalize=True) * 100
# Out:
# motivation
# Medium    48.193384
# Low       30.610687
# High      21.195929
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='motivation', data=df, order=df['motivation'].value_counts().index)
plt.title('Distribution of Student Motivation Levels')
plt.xlabel('Motivation Level')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Internet
df['internet'].value_counts()
# Out:
# internet
# Yes    10760
# No      1030
# Name: count, dtype: int64

# %%
df['internet'].value_counts(normalize= True) * 100
# Out:
# internet
# Yes    91.263783
# No      8.736217
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='internet', data=df, order=df['internet'].value_counts().index)
plt.title('Distribution of Internet Access Quality')
plt.xlabel('Internet Quality')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Learning Style
df['learningstyle'].value_counts()
# Out:
# learningstyle
# Visual         5845
# Kinesthetic    3008
# Auditory       2937
# Name: count, dtype: int64

# %%
df['learningstyle'].value_counts(normalize=True) *100
# Out:
# learningstyle
# Visual         49.575912
# Kinesthetic    25.513147
# Auditory       24.910941
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="learningstyle", data=df, order=df['learningstyle'].value_counts().index)
plt.title("Distribution of Learning Styles")
plt.xlabel("Learning Style")
plt.ylabel("Count")
plt.show()

# %%
#Check Data Distribution for EduTech
df['edutech'].value_counts()
# Out:
# edutech
# Yes    8337
# No     3453
# Name: count, dtype: int64

# %%
df['edutech'].value_counts(normalize=True)*100
# Out:
# edutech
# Yes    70.712468
# No     29.287532
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="edutech", data=df, order=df['edutech'].value_counts().index)
plt.title("Distribution of EduTech")
plt.xlabel("EduTech")
plt.ylabel("Count")
plt.show()

# %%
#Check Data Distribution for StressLevel
df['stresslevel'].value_counts()
# Out:
# stresslevel
# High      5983
# Medium    3415
# Low       2392
# Name: count, dtype: int64

# %%
df['stresslevel'].value_counts(normalize=True) * 100
# Out:
# stresslevel
# High      50.746395
# Medium    28.965225
# Low       20.288380
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='stresslevel', data=df, order=df['stresslevel'].value_counts().index)
plt.title('Distribution of Student Stress Levels')
plt.xlabel('Stress Level')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Final Grade
df['finalgrade'].value_counts()
# Out:
# finalgrade
# Fail         3225
# Good         3033
# Average      2798
# Excellent    2734
# Name: count, dtype: int64

# %%
df['finalgrade'].value_counts(normalize=True)*100
# Out:
# finalgrade
# Fail         27.353690
# Good         25.725191
# Average      23.731976
# Excellent    23.189143
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='finalgrade', data=df, order=df['finalgrade'].value_counts().index)
plt.title('Distribution of Final Grades')
plt.xlabel('Final Grade')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Resources
df['resources'].value_counts()
# Out:
# resources
# Some    7959
# Many    3831
# Name: count, dtype: int64

# %%
df['resources'].value_counts(normalize=True)*100
# Out:
# resources
# Some    67.506361
# Many    32.493639
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='resources', data=df, order=df['resources'].value_counts().index)
plt.title('Distribution of Learning Resources Access')
plt.xlabel('Resources')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Discussion
df['discussions'].value_counts()
# Out:
# discussions
# Often     7156
# Rarely    4634
# Name: count, dtype: int64

# %%
df['discussions'].value_counts(normalize=True) * 100
# Out:
# discussions
# Often     60.695505
# Rarely    39.304495
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='discussions', data=df, order=df['discussions'].value_counts().index)
plt.title('Distribution of Discussion Participation')
plt.xlabel('Discussion Frequency')
plt.ylabel('Count')
plt.show()

# %%
#Check Data Distribution for Study Hours
df['studyhours'].describe()
# Out:
# count    11790.000000
# mean        19.940543
# std          6.041473
# min          5.000000
# 25%         16.000000
# 50%         20.000000
# 75%         24.000000
# max         36.000000
# Name: studyhours, dtype: float64

# %%
df['studyhours'].skew()

''' =============NOTES==========
≈ 0 → roughly normal/symmetric

> 0 → right-skewed (long tail to the right, many low values)

< 0 → left-skewed (long tail to the left, many high values)
'''
# Out:
# np.float64(0.022967945543309495)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['studyhours'], kde=True)
plt.title('Distribution of Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Frequency')
plt.show()

# %%
#Check Data Distribution for Attendance
df['attendance'].describe()
# Out:
# count    11790.000000
# mean        80.279304
# std         11.479439
# min         60.000000
# 25%         70.000000
# 50%         80.000000
# 75%         90.000000
# max        100.000000
# Name: attendance, dtype: float64

# %%
df['attendance'].skew()
# Out:
# np.float64(-0.016654520262263172)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['attendance'], kde=True)
plt.title('Distribution of Attendance')
plt.xlabel('Attendance')
plt.ylabel('Frequency')
plt.show()

# %%
#Check Data Distribution for Age
df['age'].describe()
# Out:
# count    11790.000000
# mean        23.521883
# std          3.506763
# min         18.000000
# 25%         20.000000
# 50%         24.000000
# 75%         27.000000
# max         29.000000
# Name: age, dtype: float64

# %%
#Check Data Distribution for Age
df['age'].skew()
# Out:
# np.float64(-0.010417004856915713)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Check Data Distribution for OnlineCourses
df['onlinecourses'].describe()
# Out:
# count    11790.000000
# mean         9.872180
# std          6.116135
# min          0.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         20.000000
# Name: onlinecourses, dtype: float64

# %%
df['onlinecourses'].skew()
# Out:
# np.float64(0.025499505174449405)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['onlinecourses'], kde=True)
plt.title('Distribution of Online Courses')
plt.xlabel('Online Courses')
plt.ylabel('Frequency')
plt.show()

# %%
#Check Data Distribution for Assignment Completion
df['assignmentcompletion'].describe()
# Out:
# count    11790.000000
# mean        74.499321
# std         14.646308
# min         50.000000
# 25%         62.000000
# 50%         74.000000
# 75%         87.000000
# max        100.000000
# Name: assignmentcompletion, dtype: float64

# %%
df['assignmentcompletion'].skew()
# Out:
# np.float64(0.049237643103892906)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['assignmentcompletion'], kde=True)
plt.title('Distribution of Assignment Completion')
plt.xlabel('Assignment Completion')
plt.ylabel('Frequency')
plt.show()

# %%
#Check Data Distribution for Exam Score
df['examscore'].describe()
# Out:
# count    11790.000000
# mean        70.359033
# std         17.681159
# min         40.000000
# 25%         55.000000
# 50%         70.000000
# 75%         86.000000
# max        100.000000
# Name: examscore, dtype: float64

# %%
df['examscore'].skew()
# Out:
# np.float64(-0.020255876622841975)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['examscore'], kde=True)
plt.title('Distribution of Exam Score')
plt.xlabel('Exam Score')
plt.ylabel('Frequency')
plt.show()
